# %%
# %pip install openai
dbutils.library.restartPython()

# %%
import os
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = "paste-your-key-here"  # temporary for portfolio testing only

client = OpenAI()
