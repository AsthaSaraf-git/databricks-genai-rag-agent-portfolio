# %%
quality_df = spark.table("workspace.default.gold_quality_by_table")

rows = quality_df.collect()

context = ""

for row in rows:
    context += f"""
Table: {row['table_name']}
Quality Score: {row['quality_score']}
Failed Rules: {row['failed_rules']}
Total Rules: {row['total_rules']}
"""

print(context)
